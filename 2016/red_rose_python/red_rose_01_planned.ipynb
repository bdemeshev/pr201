# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import bokeh as bk

# %%
import numpy as np

# %%
import ggplot as gg

# %%
pok = pd.read_csv("/Users/boris/Downloads/pokemon-sun-and-moon-gen-7-stats/pokemon.csv")

# %%
pok.head()
# Out:
#    id  ndex     species       forme  type1   type2  ability1 ability2  \
# 0   1     1   Bulbasaur   Bulbasaur  Grass  Poison  Overgrow      NaN
# 1   2     2     Ivysaur     Ivysaur  Grass  Poison  Overgrow      NaN
# 2   3     3    Venusaur    Venusaur  Grass  Poison  Overgrow      NaN
# 3   4     4  Charmander  Charmander   Fire     NaN     Blaze      NaN
# 4   5     5  Charmeleon  Charmeleon   Fire     NaN     Blaze      NaN
#
#       abilityH  hp    ...          weight  height  dex1  dex2           class  \
# 0  Chlorophyll  45    ...       15.2 lbs.   2'04"   NaN   NaN    Seed Pokémon
# 1  Chlorophyll  60    ...       28.7 lbs.   3'03"   NaN   NaN    Seed Pokémon
# 2  Chlorophyll  80    ...      220.5 lbs.   6'07"   NaN   NaN    Seed Pokémon
# 3  Solar Power  39    ...       18.7 lbs.   2'00"   NaN   NaN  Lizard Pokémon
# 4  Solar Power  58    ...       41.9 lbs.   3'07"   NaN   NaN   Flame Pokémon
#
#    percent-male percent-female pre-evolution egg-group1 egg-group2
# ...

# %%
pok.tail()
# Out:
#         id  ndex   species                      forme   type1     type2  \
# 1056  1058   778   Mimikyu      Mimikyu (Busted Form)   Ghost     Fairy
# 1057  1059   778   Mimikyu                Mimikyu (2)   Ghost     Fairy
# 1058  1060   778   Mimikyu                Mimikyu (3)   Ghost     Fairy
# 1059  1061   784   Kommo-o                Kommo-o (1)  Dragon  Fighting
# 1060  1062   801  Magearna  Magearna (Original Color)   Steel     Fairy
#
#          ability1    ability2    abilityH  hp    ...          weight  height  \
# 1056     Disguise    Disguise    Disguise  60    ...        1.5 lbs.   0'08"
# 1057     Disguise    Disguise    Disguise  60    ...        1.5 lbs.   0'08"
# 1058     Disguise    Disguise    Disguise  60    ...        1.5 lbs.   0'08"
# 1059  Bulletproof  Soundproof    Overcoat  75    ...      172.4 lbs.   5'03"
# 1060   Soul-Heart  Soul-Heart  Soul-Heart  80    ...      177.5 lbs.   3'03"
#
#                                                    dex1  \
# ...

# %%
pok.describe()
# Out:
# /Users/boris/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                 id         ndex           hp       attack      defense  \
# count  1061.000000  1061.000000  1061.000000  1061.000000  1061.000000
# mean    531.244109   417.471254    70.041470    79.602262    73.730443
# std     306.748505   239.020743    25.893508    31.378369    30.394899
# min       1.000000     1.000000     1.000000     5.000000     5.000000
# 25%     266.000000   201.000000    50.000000    55.000000    50.000000
# 50%     531.000000   423.000000    68.000000    75.000000    70.000000
# 75%     796.000000   646.000000    80.000000   100.000000    91.000000
# max    1062.000000   802.000000   255.000000   190.000000   230.000000
#
#           spattack    spdefense        speed        total  percent-male  \
# count  1061.000000  1061.000000  1061.000000  1061.000000    859.000000
# ...

# %%
pok.columns
# Out:
# Index(['id', 'ndex', 'species', 'forme', 'type1', 'type2', 'ability1',
#        'ability2', 'abilityH', 'hp', 'attack', 'defense', 'spattack',
#        'spdefense', 'speed', 'total', 'weight', 'height', 'dex1', 'dex2',
#        'class', 'percent-male', 'percent-female', 'pre-evolution',
#        'egg-group1', 'egg-group2'],
#       dtype='object')

# %%
pok_two = pok[['percent-female', 'attack']]

# %%
pok_two.describe()
# Out:
# /Users/boris/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        percent-female       attack
# count      859.000000  1061.000000
# mean         0.455471    79.602262
# std          0.207969    31.378369
# min          0.000000     5.000000
# 25%               NaN    55.000000
# 50%               NaN    75.000000
# 75%               NaN   100.000000
# max          1.000000   190.000000

# %%
pok_3 = pok[(pok.attack > 80) & (pok.defense > 90)]

# %%
pok_3.describe()
# Out:
# /Users/boris/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                 id        ndex          hp      attack     defense  \
# count   187.000000  187.000000  187.000000  187.000000  187.000000
# mean    666.764706  473.914439   88.363636  114.122995  115.251337
# std     300.750492  233.609828   23.892374   23.053021   22.635398
# min       9.000000    3.000000   45.000000   81.000000   94.000000
# 25%     451.000000  304.000000   71.000000   95.000000  100.000000
# 50%     763.000000  492.000000   90.000000  110.000000  115.000000
# 75%     925.500000  711.000000  100.000000  125.000000  121.500000
# max    1062.000000  801.000000  216.000000  190.000000  230.000000
#
#          spattack   spdefense       speed       total  percent-male  \
# count  187.000000  187.000000  187.000000  187.000000     100.00000
# ...

# %%
pok_3_sorted = pok_3.sort_values(by = 'attack')

# %%
pok_3_sorted.head()
# Out:
#       id  ndex    species      forme  type1     type2      ability1 ability2  \
# 345  346   346    Cradily    Cradily   Rock     Grass  Suction Cups      NaN
# 736  737   737  Charjabug  Charjabug    Bug  Electric       Battery  Battery
# 153  154   154   Meganium   Meganium  Grass       NaN      Overgrow      NaN
# 8      9     9  Blastoise  Blastoise  Water       NaN       Torrent      NaN
# 367  368   368   Gorebyss   Gorebyss  Water       NaN    Swift Swim      NaN
#
#         abilityH  hp    ...          weight  height  \
# 345  Storm Drain  86    ...      133.2 lbs.   4'11"
# 736      Battery  57    ...       23.1 lbs.   1'08"
# 153   Leaf Guard  80    ...      221.6 lbs.   5'11"
# 8      Rain Dish  79    ...      188.5 lbs.   5'03"
# 367    Hydration  55    ...       49.8 lbs.   5'11"
#
#                                                   dex1  \
# 345                                                NaN
# 736  Its body is capable of storing electricity. On...
# ...

# %%
pok_3[1:4]
# Out:
#     id  ndex    species      forme   type1     type2      ability1 ability2  \
# 27  28    28  Sandslash  Sandslash  Ground       NaN     Sand Veil      NaN
# 61  62    62  Poliwrath  Poliwrath   Water  Fighting  Water Absorb     Damp
# 74  75    75   Graveler   Graveler    Rock    Ground     Rock Head   Sturdy
#
#       abilityH  hp    ...          weight  height  \
# 27   Sand Rush  75    ...       65.0 lbs.   3'03"
# 61  Swift Swim  90    ...      119.0 lbs.   4'03"
# 74   Sand Veil  55    ...      231.5 lbs.   3'03"
#
#                                                  dex1  \
# 27  Although they are sharp, its claws and spikes ...
# 61  Poliwrath in the Alola region are strong swimm...
# 74  Mossy rocks are its favorite food. It can devo...
#
#                                                  dex2            class  \
# 27  It uses its claws to climb trees and then curl...    Mouse Pokémon
# 61  Its percentage of body fat is nearly zero. Its...  Tadpole Pokémon
# ...

# %%
pok_3[['attack', 'defense']]
# Out:
#       attack  defense
# 8         83      100
# 27       100      110
# 61        95       95
# 74        95      115
# 75       120      130
# 90        95      180
# 98       130      115
# 109       90      120
# 110       85       95
# 111      130      120
# 126      125      100
# 127      100       95
# 140      115      105
# 143       85      100
# 148      134       95
# 150      100      100
# 153       82      100
# 159      105      100
# 184      100      115
# 204       90      140
# 207       85      200
# 211      130      100
# 229       95       95
# 231      120      120
# 236       95       95
# 247      134      110
# 248       90      130
# 250      100      100
# 288      160      100
# 304       90      140
# ...      ...      ...
# 956      120       95
# 957      120       95
# 958      120       95
# 1007      85      122
# 1008      95      122
# 1009     100      122
# 1010     131       95
# 1013     100      121
# 1014     100      121
# ...

# %%
2:3
# Out:
#   File "<ipython-input-31-5d229580e485>", line 1
#     2:3
#      ^
# SyntaxError: invalid syntax

# %%
pok_3.head()
# Out:
#     id  ndex    species      forme   type1     type2      ability1 ability2  \
# 8    9     9  Blastoise  Blastoise   Water       NaN       Torrent      NaN
# 27  28    28  Sandslash  Sandslash  Ground       NaN     Sand Veil      NaN
# 61  62    62  Poliwrath  Poliwrath   Water  Fighting  Water Absorb     Damp
# 74  75    75   Graveler   Graveler    Rock    Ground     Rock Head   Sturdy
# 75  76    76      Golem      Golem    Rock    Ground     Rock Head   Sturdy
#
#       abilityH  hp    ...          weight  height  \
# 8    Rain Dish  79    ...      188.5 lbs.   5'03"
# 27   Sand Rush  75    ...       65.0 lbs.   3'03"
# 61  Swift Swim  90    ...      119.0 lbs.   4'03"
# 74   Sand Veil  55    ...      231.5 lbs.   3'03"
# 75   Sand Veil  80    ...      661.4 lbs.   4'07"
#
#                                                  dex1  \
# 8                                                 NaN
# 27  Although they are sharp, its claws and spikes ...
# ...

# %%
pok_3.new_var = pok_3.attack + pok_3.defense

# %%
pok_3.new_var
# Out:
# 8       183
# 27      210
# 61      190
# 74      210
# 75      250
# 90      275
# 98      245
# 109     210
# 110     180
# 111     250
# 126     225
# 127     195
# 140     220
# 143     185
# 148     229
# 150     200
# 153     182
# 159     205
# 184     215
# 204     230
# 207     285
# 211     230
# 229     190
# 231     240
# 236     190
# 247     244
# 248     220
# 250     200
# 288     260
# 304     230
#        ...
# 956     215
# 957     215
# 958     215
# 1007    207
# 1008    217
# 1009    222
# 1010    226
# 1013    221
# 1014    221
# 1015    270
# 1023    270
# 1026    190
# 1027    190
# 1028    190
# 1029    190
# 1030    190
# 1031    190
# 1032    190
# 1033    190
# 1034    190
# 1035    190
# 1036    190
# 1037    190
# 1038    190
# 1039    190
# 1040    190
# 1041    190
# 1042    190
# 1059    235
# 1060    210
# dtype: int64

# %%
my_data = pd.DataFrame({'col_A' : [1, 3, 4], 'col_B' : [5., 6., 7.]})

# %%
my_data
# Out:
#    col_A  col_B
# 0      1    5.0
# 1      3    6.0
# 2      4    7.0

# %%
pok_3.head()
# Out:
#     id  ndex    species      forme   type1     type2      ability1 ability2  \
# 8    9     9  Blastoise  Blastoise   Water       NaN       Torrent      NaN
# 27  28    28  Sandslash  Sandslash  Ground       NaN     Sand Veil      NaN
# 61  62    62  Poliwrath  Poliwrath   Water  Fighting  Water Absorb     Damp
# 74  75    75   Graveler   Graveler    Rock    Ground     Rock Head   Sturdy
# 75  76    76      Golem      Golem    Rock    Ground     Rock Head   Sturdy
#
#       abilityH  hp    ...          weight  height  \
# 8    Rain Dish  79    ...      188.5 lbs.   5'03"
# 27   Sand Rush  75    ...       65.0 lbs.   3'03"
# 61  Swift Swim  90    ...      119.0 lbs.   4'03"
# 74   Sand Veil  55    ...      231.5 lbs.   3'03"
# 75   Sand Veil  80    ...      661.4 lbs.   4'07"
#
#                                                  dex1  \
# 8                                                 NaN
# 27  Although they are sharp, its claws and spikes ...
# ...

# %%
pok_3.iloc[0:3, 0]
# Out:
# 8      9
# 27    28
# 61    62
# Name: id, dtype: int64

# %%
a = [1, 2, 3, 4, 7]

# %%
a[0]
# Out:
# 1

# %%
a[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-52-b6a934feab86> in <module>()
# ----> 1 a[5]
#
# IndexError: list index out of range

# %%
type(a)
# Out:
# list

# %%
sns.set(style="darkgrid")
a = sns.interactplot(x1='attack', x2='defense', y='hp', data=pok_3)

# %%
sns.pairplot(pok_3[['attack', 'defense', 'hp']])

# %%
sns.jointplot(data=pok_3, x='attack', y='defense')

# %%
help(sns.jointplot)
# Out:
# Help on function jointplot in module seaborn.distributions:
#
# jointplot(x, y, data=None, kind='scatter', stat_func=<function pearsonr at 0x11590b2f0>, color=None, size=6, ratio=5, space=0.2, dropna=True, xlim=None, ylim=None, joint_kws=None, marginal_kws=None, annot_kws=None, **kwargs)
#     Draw a plot of two variables with bivariate and univariate graphs.
#
#     This function provides a convenient interface to the :class:`JointGrid`
#     class, with several canned plot kinds. This is intended to be a fairly
#     lightweight wrapper; if you need more flexibility, you should use
#     :class:`JointGrid` directly.
#
#     Parameters
#     ----------
#     x, y : strings or vectors
#         Data or names of variables in ``data``.
#     data : DataFrame, optional
#         DataFrame when ``x`` and ``y`` are variable names.
#     kind : { "scatter" | "reg" | "resid" | "kde" | "hex" }, optional
#         Kind of plot to draw.
#     stat_func : callable or None, optional
# ...

# %%
help(sns.barplot)
# Out:
# Help on function barplot in module seaborn.categorical:
#
# barplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, estimator=<function mean at 0x10579c0d0>, ci=95, n_boot=1000, units=None, orient=None, color=None, palette=None, saturation=0.75, errcolor='.26', errwidth=None, capsize=None, ax=None, **kwargs)
#     Show point estimates and confidence intervals as rectangular bars.
#
#     A bar plot represents an estimate of central tendency for a numeric
#     variable with the height of each rectangle and provides some indication of
#     the uncertainty around that estimate using error bars. Bar plots include 0
#     in the quantitative axis range, and they are a good choice when 0 is a
#     meaningful value for the quantitative variable, and you want to make
#     comparisons against it.
#
#     For datasets where 0 is not a meaningful value, a point plot will allow you
#     to focus on differences between levels of one or more categorical
#     variables.
#
# ...

# %%
sns.distplot(pok_3.attack)
# Out:
# /Users/boris/anaconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
np.random.seed(42)
x = np.random.binomial(n=10, p=0.3, size=20)

# %%
sns.distplot(x)
# Out:
# /Users/boris/anaconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
help(sns.distplot)
# Out:
# Help on function distplot in module seaborn.distributions:
#
# distplot(a, bins=None, hist=True, kde=True, rug=False, fit=None, hist_kws=None, kde_kws=None, rug_kws=None, fit_kws=None, color=None, vertical=False, norm_hist=False, axlabel=None, label=None, ax=None)
#     Flexibly plot a univariate distribution of observations.
#
#     This function combines the matplotlib ``hist`` function (with automatic
#     calculation of a good default bin size) with the seaborn :func:`kdeplot`
#     and :func:`rugplot` functions. It can also fit ``scipy.stats``
#     distributions and plot the estimated PDF over the data.
#
#     Parameters
#     ----------
#
#     a : Series, 1d-array, or list.
#         Observed data. If this is a Series object with a ``name`` attribute,
#         the name will be used to label the data axis.
#     bins : argument for matplotlib hist(), or None, optional
#         Specification of hist bins, or None to use Freedman-Diaconis rule.
#     hist : bool, optional
# ...
