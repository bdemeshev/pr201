# %% [markdown]
# Призываем верных демонов и произносим магическое заклинание для быстрого построения графиков:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import bokeh as bk
# %matplotlib inline

# %% [markdown]
# Создадим случайную величину X имеющую биномиальное распределение:

# %%
X = stats.binom(n=30, p=0.7)

# %% [markdown]
# Математическое ожидание:

# %%
X.expect()
# Out:
# 20.999999999999847

# %% [markdown]
# Дисперсия:

# %%
X.var()
# Out:
# 6.3000000000000007

# %% [markdown]
# Найдём вероятность $P(X=7)$:

# %%
X.pmf(7)
# Out:
# 1.5783752006340861e-07

# %% [markdown]
# Найдём вероятность $P(X=0)$:

# %%
X.pmf(0)
# Out:
# 2.0589113209464959e-16

# %% [markdown]
# Почему у нас вышли не идеально точные результаты? Давайте разберёмся!

# %%
4 - 3 == 1
# Out:
# True

# %%
0.4 - 0.3 == 0.1
# Out:
# False

# %% [markdown]
# Проблема в том, что десятичные числа при преобразовании в двоичную систему могут стать периодическими с бесконечной записью!

# %%
0.1 + 0.3 == 0.4
# Out:
# True

# %% [markdown]
# Сгенерируем случайный вектор из 20 независимых значений нашего биномиального распределения:

# %%
values = X.rvs(20)

# %%
values
# Out:
# array([23, 24, 14, 21, 17, 25, 17, 21, 21, 22, 24, 20, 18, 21, 21, 19, 21,
#        22, 22, 21])

# %% [markdown]
# Найдём вероятность $F(10)=P(X \leq 10)$:

# %%
X.cdf(10)
# Out:
# 3.6870080768784921e-05

# %% [markdown]
# Последовательность чисел от 2 до 8:

# %%
v = np.arange(2, 8)

# %%
v
# Out:
# array([2, 3, 4, 5, 6, 7])

# %% [markdown]
# Арифметическая прогрессия:

# %%
np.arange(start=2, stop=8, step=0.3)
# Out:
# array([ 2. ,  2.3,  2.6,  2.9,  3.2,  3.5,  3.8,  4.1,  4.4,  4.7,  5. ,
#         5.3,  5.6,  5.9,  6.2,  6.5,  6.8,  7.1,  7.4,  7.7])

# %% [markdown]
# Снова вернёмся к нашему вектору от 2 до 8:

# %%
v = np.arange(2, 8)

# %%
X.pmf(v)
# Out:
# array([  4.87618831e-13,   1.06192545e-11,   1.67253259e-10,
#          2.02933954e-09,   1.97296900e-08,   1.57837520e-07])

# %% [markdown]
# А это $P(X \in [2; 8))$:

# %%
np.sum(X.pmf(v))
# Out:
# 1.797749097474779e-07

# %% [markdown]
# На этот раз сгенерируем 1000 независимых значений случайной величины:

# %%
values = X.rvs(1000)

# %%
values
# Out:
# array([22, 22, 23, 18, 23, 19, 23, 25, 23, 18, 20, 19, 23, 25, 24, 21, 18,
#        23, 22, 22, 19, 23, 21, 22, 16, 19, 23, 18, 21, 20, 16, 23, 22, 21,
#        27, 22, 14, 18, 19, 21, 20, 23, 22, 25, 20, 18, 17, 25, 14, 23, 19,
#        19, 28, 17, 23, 20, 22, 22, 23, 21, 25, 19, 24, 20, 23, 21, 20, 17,
#        22, 20, 23, 18, 21, 20, 19, 26, 21, 23, 20, 24, 26, 23, 20, 19, 24,
#        10648,  4096,  9261, 12167,  8000,  8000, 10648, 10648, 13824,
#         9261,  6859, 12167,  9261,  8000, 13824, 10648,  8000,  6859,
#        13824,  6859, 10648,  8000,  4096,  9261,  6859, 10648, 12167,
#         6859, 19683, 10648, 12167,  9261,  6859, 13824,  8000, 10648,
#         8000, 12167,  4913, 15625,  9261,  8000, 10648,  5832, 10648,
#         8000,  8000,  9261, 15625, 15625,  4913,  8000,  9261, 10648,
#         6859, 10648, 10648,  8000,  8000,  8000, 10648, 12167,  9261,
#         6859,  8000,  5832, 10648, 12167,  8000,  6859,  6859,  8000,
#        12167,  6859, 12167,  5832, 13824, 10648,  9261, 10648, 12167,
#         9261,  8000,  8000, 15625,  8000,  9261,  6859,  6859,  6859,
#         9261, 10648,  9261, 10648, 13824,  9261,  8000,  8000,  8000,
#         9261,  9261,  6859,  5832, 12167,  8000,  8000, 10648,  9261,
#         8000,  8000, 12167,  6859,  5832,  8000, 10648,  6859, 15625,
#        12167, 10648, 10648, 10648,  9261,  9261,  9261, 15625,  9261,
#         8000,  5832,  3375,  4096, 10648,  4096,  6859,  9261, 12167,
#         4913,  9261, 10648, 21952, 10648,  8000, 12167, 21952, 13824,
#         4913,  4913,  5832, 13824,  8000, 12167, 10648,  6859,  4913,
#        12167, 13824,  4096, 12167, 12167,  4913,  8000,  4913, 10648,
#        12167,  8000, 12167,  9261,  4096,  8000,  9261, 12167, 15625,
#        12167, 15625, 10648,  9261, 12167,  4913,  9261,  5832, 13824,
#         9261, 10648,  9261,  4096,  5832, 12167,  8000, 10648, 15625,
#         6859,  8000, 13824,  8000,  6859, 12167,  5832, 10648,  4913,
#        15625, 15625, 10648,  8000, 13824,  6859,  6859,  4913, 12167,
#        10648,  9261,  8000,  9261,  9261,  6859,  8000,  9261, 10648,
#         8000, 10648,  8000,  9261, 12167,  6859,  4913,  8000, 12167,
#        13824,  9261,  5832,  5832,  4096, 12167,  8000, 17576,  8000,
#        10648,  9261, 12167, 12167, 12167,  6859,  8000,  4913,  8000,
#         8000, 10648, 12167, 10648,  9261, 15625, 10648,  8000,  8000,
#         8000,  6859,  3375,  9261,  5832,  5832,  9261, 12167,  8000,
#        10648, 13824, 12167,  6859, 12167,  9261, 13824,  4913, 12167,
#        12167,  6859,  6859,  5832,  4913,  6859, 10648, 13824, 13824,  9261])

# %% [markdown]
# Среднее арифметическое или оценка для $E(X^3)$:

# %%
np.mean(values ** 3)
# Out:
# 9673.357

# %% [markdown]
# Оценка для математического ожидания:

# %%
np.mean(values)
# Out:
# 21.013000000000002

# %% [markdown]
# Деление нацело:

# %%
82 // 13
# Out:
# 6

# %% [markdown]
# Остаток от деления:

# %%
82 % 13
# Out:
# 4

# %%
49 % 13
# Out:
# 10

# %% [markdown]
# Установим зерно генератора случайных чисел:

# %%
np.random.seed(7)

# %%
v = X.rvs(50)

# %%
np.sum(v > 20)
# Out:
# 32
