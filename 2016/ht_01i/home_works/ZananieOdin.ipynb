# %%
import numpy as n

# %%
import pandas as pn

# %%
import seaborn as s

# %%
matplotlib inline

# %%
eng = pn.read_csv('/Users/HP/Desktop/oil.csv')

# %%
eng.head(10)
# Out:
#    Consumption  Production    Imports    Exports  Year
# 0    97.301269   78.095827  28.587117  10.355611  2011
# 1    97.722053   74.806092  29.877112   8.233777  2010
# 2    94.559407   72.656971  29.705660   6.964591  2009
# 3    99.274527   73.111145  32.991936   7.059825  2008
# 4   101.295961   71.373190  34.703020   5.482293  2007
# 5    99.629469   70.782157  34.678725   4.872427  2006
# 6   100.281511   69.427669  34.708994   4.559866  2005
# 7   100.161797   70.187684  33.543709   4.433962  2004
# 8    97.977655   70.039770  31.061012   4.054205  2003
# 9    97.645118   70.716137  29.408149   3.668724  2002

# %%
eng.columns
# Out:
# Index(['Consumption', 'Production', 'Imports', 'Exports', 'Year'], dtype='object')

# %%
s.jointplot(data = eng, x = 'Year', y = 'Production', color = 'Black')

# %%
s.jointplot(data = eng, x = 'Year', y = 'Consumption', color = 'Orange')

# %%
s.jointplot(data = eng, x = 'Year', y = 'Exports', color = 'Yellow')

# %%
s.jointplot(data = eng, x = 'Year', y = 'Imports', color = 'Grey')

# %%
ene = pn.read_csv('/Users/HP/Desktop/oil1.csv')

# %%
ene.head(10)
# Out:
#    Unnamed: 0  Residential  Commercial  Industrial  Transportation  Year
# 0         NaN      1.16218     0.99156     1.48160         1.84528  2011
# 1         NaN      1.21245     1.02716     1.49373         1.87909  2010
# 2         NaN      1.15921     1.00837     1.40075         1.86032  2009
# 3         NaN      1.22939     1.07369     1.59878         1.93654  2008
# 4         NaN      1.24125     1.07809     1.66072         2.03951  2007
# 5         NaN      1.19201     1.04339     1.66178         2.02186  2006
# 6         NaN      1.26146     1.06903     1.67535         1.99074  2005
# 7         NaN      1.22776     1.05350     1.73175         1.96232  2004
# 8         NaN      1.23009     1.03603     1.69188         1.89892  2003
# 9         NaN      1.20263     1.02629     1.68503         1.89220  2002

# %%
s.jointplot(data = ene, x = 'Year', y = 'Residential', color = 'Blue')

# %%
s.jointplot(data = ene, x = 'Year', y = 'Commercial', color = 'Green')

# %%
s.jointplot(data = ene, x = 'Year', y = 'Industrial', color = 'White')

# %%
s.jointplot(data = ene, x = 'Year', y = 'Transportation', color = 'Brown')

# %%
maj = pn.read_csv('/Users/HP/Desktop/oil2.csv')

# %%
maj.head(10)
# Out:
#    Unnamed: 0       Coal  Natural Gas  Crude Oil  Nuclear Electric Power  \
# 0         NaN  22.180926    23.506181  11.985743                8.259432
# 1         NaN  22.038226    21.823065  11.592618                8.434433
# 2         NaN  21.623721    21.139450  11.348257                8.356019
# 3         NaN  23.851368    20.702884  10.508538                8.427297
# 4         NaN  23.492742    19.786209  10.721012                8.455364
# 5         NaN  23.789510    19.021706  10.801102                8.215414
# 6         NaN  23.185189    18.556014  10.962615                8.160810
# 7         NaN  22.852099    19.074254  11.503140                8.221985
# 8         NaN  22.093652    19.633304  12.026028                7.958858
# 9         NaN  22.732237    19.382055  12.163319                8.145429
#
#    Hydroelectric Power   Biomass  Natural Gas Plant Liquids  \
# 0             3.171422  4.511456                   2.927854
# ...

# %%
maj.columns
# Out:
# Index(['Unnamed: 0', 'Coal', 'Natural Gas', 'Crude Oil',
#        'Nuclear Electric Power', 'Hydroelectric Power', 'Biomass',
#        'Natural Gas Plant Liquids', 'Other Renewable Energy¹', 'Year'],
#       dtype='object')

# %%
s.jointplot(data = maj, x = 'Year', y = 'Coal', color = 'Brown')

# %%
s.jointplot(data = maj, x = 'Year', y = 'Natural Gas', color = 'Brown')

# %%
s.jointplot(data = maj, x = 'Year', y = 'Crude Oil', color = 'Brown')
