# %% [markdown]
# # Домашнее задание
#
# Субботкина Анастасия БЭК 151

# %% [markdown]
# _Подходит к концу високосный год - поговорим о смерти..._

# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

df = pandas.DataFrame(dict(graph=['80-84', '70-74', '60-64', '40-44', '30-34', '15-19', '<1'],
                           n=[2847, 3581, 2320, 99, 10, 0, 0], m=[502, 421, 241, 25, 6, 0, 0])) 

ind = np.arange(len(df))
width = 0.4

fig, ax = plt.subplots()
ax.barh(ind, df.n, width, color='red', label='men 2015')
ax.barh(ind + width, df.m, width, color='green', label='women 2015')

ax.set(yticks=ind + width, yticklabels=df.graph, ylim=[2*width - 1, len(df)])
ax.legend()
plt.title('Lung cancer')
ax.set_ylabel('Age')
ax.set_xlabel('The mortality rate')
plt.grid(True)
plt.show()

# %% [markdown]
# Смертность мужчин в 2015 году по причине рака легких значительно превосходит коэффициент смертности женщин. Заболевание начинает сильно влиять на жизненный цикл с 40-44 лет, достигая пика в возрасте 70-74 года у мужчин.

# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

df = pandas.DataFrame(dict(graph=['80-84', '70-74', '60-64', '40-44', '30-34', '15-19', '<1'],
                           n=[2847, 3581, 2320, 99, 10, 0, 0], m=[3261, 3737, 3405, 115, 13, 1, 0])) 

ind = np.arange(len(df))
width = 0.4

fig, ax = plt.subplots()
ax.barh(ind, df.n, width, color='red', label='men 2015')
ax.barh(ind + width, df.m, width, color='green', label='men 2011')

ax.set(yticks=ind + width, yticklabels=df.graph, ylim=[2*width - 1, len(df)])
ax.legend()
plt.title('Lung cancer')
ax.set_ylabel('Age')
ax.set_xlabel('The mortality rate (per 1000000 people)')
plt.grid(True)
plt.show()

# %% [markdown]
# Сраванивая смертность мужчин от рака легких в 2011 и 2015 годах, можно сделать вывод, что в последние годы смертность по этой причине падает. Кроме того, если в 2015 году в возрасте 60-64 лет от рака легких умирало даже больше, чем в 80-84 года, то сегодня это значение намного ниже.

# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

df = pandas.DataFrame(dict(graph=['80-84', '70-74', '60-64', '40-44', '30-34', '15-19', '<1'],
                           n=[502, 421, 241, 25, 6, 0, 0], m=[552, 381, 242, 27, 7, 1, 1])) 

ind = np.arange(len(df))
width = 0.4

fig, ax = plt.subplots()
ax.barh(ind, df.n, width, color='red', label='women 2015')
ax.barh(ind + width, df.m, width, color='green', label='women 2011')

ax.set(yticks=ind + width, yticklabels=df.graph, ylim=[2*width - 1, len(df)])
ax.legend()
plt.title('Lung cancer')
ax.set_ylabel('Age')
ax.set_xlabel('The mortality rate')
plt.grid(True)
plt.show()

# %% [markdown]
# Изменение коэффициента смертности от рака легких для женщин неоднозначно. Значения почти одинаковы до 65 лет, потом смертность 2015 года превосходит показатель 2011. Однако с 80 лет в 2011 году от этого заболевания умерло больше женщин, чем в 2015.

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 7
ind = np.arange(N)  
width = 0.27       

fig = plt.figure()
ax = fig.add_subplot(111)

yvals = [135, 11, 132, 273, 655, 907, 1653]
rects1 = ax.bar(ind, yvals, width, color='blue')
zvals = [131, 6, 52, 75, 130, 260, 736]
rects2 = ax.bar(ind+width, zvals, width, color='orange')

plt.title('Pneumonia')
ax.set_ylabel('The mortality rate')
ax.set_xlabel('Age')
ax.set_xticks(ind+width)
ax.set_xticklabels( ('<1', '15-19', '30-34', '40-44', '60-64', '70-74', '80-84') )
ax.legend( (rects1[0], rects2[0]), ('men 2015', 'women 2015') )
plt.grid(True)
plt.show()

# %% [markdown]
# В младенческом возрасте смертность от пневмонии примерно равна среди маленьких девочек и мальчиков. Однако с 30-34 лет смертность мужчин от этого заболевания превосходит смертность женщин в несколько раз, рост коэффициента наблюдается на протяжении врего периода с 30 лет.

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 7
ind = np.arange(N)  
width = 0.27       

fig = plt.figure()
ax = fig.add_subplot(111)

yvals = [135, 11, 132, 273, 655, 907, 1653]
rects1 = ax.bar(ind, yvals, width, color='blue')
zvals = [261, 15, 243, 379, 821, 889, 1323]
rects2 = ax.bar(ind+width, zvals, width, color='orange')

plt.title('Pneumonia')
ax.set_ylabel('The mortality rate')
ax.set_xlabel('Age')
ax.set_xticks(ind+width)
ax.set_xticklabels( ('<1', '15-19', '30-34', '40-44', '60-64', '70-74', '80-84') )
ax.legend( (rects1[0], rects2[0]), ('men 2015', 'men 2011') )
plt.grid(True)
plt.show()

# %% [markdown]
# Смертность мужчин от пневмонии в 2011 году превосходит смертность в 2015 с младенчества до 64 лет. Потом значение  преобладает в 2015 году, однако тренд роста совпадает (достигая максимума в 70-74 года).

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 7
ind = np.arange(N)  
width = 0.27       

fig = plt.figure()
ax = fig.add_subplot(111)

yvals = [131, 6, 52, 75, 130, 260, 736]
rects1 = ax.bar(ind, yvals, width, color='blue')
zvals = [229, 7, 84, 103, 132, 208, 556]
rects2 = ax.bar(ind+width, zvals, width, color='orange')

plt.title('Pneumonia')
ax.set_ylabel('The mortality rate')
ax.set_xlabel('Age')
ax.set_xticks(ind+width)
ax.set_xticklabels( ('<1', '15-19', '30-34', '40-44', '60-64', '70-74', '80-84') )
ax.legend( (rects1[0], rects2[0]), ('women 2015', 'women 2011') )
plt.grid(True)
plt.show()

# %% [markdown]
# Если в младенчестве и с 30 до 65 лет смертность от пневмонии у женщин в 2011 году была больше, чем в 2015, то с 70 лет значения 2015 преобладают над значениями 2011. Показатель 2011 года в младенчестве примерно равен показателю в семидесятилетнем возрасте.

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 7
ind = np.arange(N)        

fig = plt.figure()
ax = fig.add_subplot(111)

y = [0, 0, 10, 99, 2320, 3581, 2847]
ax.plot (y, color='b', label='Lung cancer')
y = [135, 11, 132, 273, 655, 907, 1653]
ax.plot (y, color='r', label='Pneumonia')
z = [162, 426, 1108, 1191, 1160, 1032, 1324]
ax.plot(z, color='g', label='Injuries')


ax.set_ylabel('The mortality rate')
ax.set_xlabel('Age')
plt.title('Men 2015')
ax.set_xticklabels( ('<1', '15-19', '30-34', '40-44', '60-64', '70-74', '80-84') )
ax.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# В 2015 году смертность мужчин от внешних трамв с младенчества до 50 лет больше, чем от других заболеваний, однако потом она остается примерно на том же уровне, тогда как резко растет смертность от рака легких, а с 74 лет и от пневмонии.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
N = 7
ind = np.arange(N)        

fig = plt.figure()
ax = fig.add_subplot(111)

y = [0, 0, 6, 25, 241, 421, 502]
ax.plot (y, color='b', label='Lung cancer')
y = [131, 6, 52, 75, 130, 260, 736]
ax.plot (y, color='r', label='Pneumonia')
z = [124, 169, 213, 244, 244, 314, 447]
ax.plot(z, color='g', label='Injuries')


ax.set_ylabel('The mortality rate')
ax.set_xlabel('Age')
plt.title('Women 2015')
ax.set_xticklabels( ('<1', '15-19', '30-34', '40-44', '60-64', '70-74', '80-84') )
ax.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Тренд женской смертности схож с мужской, однако значения намного меньше, а пневмония в преклонном возрасте является более серьезной проблемой, чем рак легких.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

age = ["<1", "15-19", "30-34", "40-44", "60-64", "70-74", "80-84"]
m = np.array([162, 426, 1108, 1191, 1160, 1032, 1324])
w = [124, 169, 213, 244, 244, 314, 447]

idx = m.argsort()
age, m, w = [np.take(x, idx) for x in [age, m, w]]

y = np.arange(w.size)

fig, axes = plt.subplots(ncols=2, sharey=True)
axes[0].barh(y, m, align='center' , color='orange', zorder=10)
axes[0].set(title='Men injuries 2015')
axes[1].barh(y, w, align='center', color='orange', zorder=10)
axes[1].set(title='Women injuries 2015')

axes[0].invert_xaxis()
axes[0].set(yticks=y, yticklabels=age)
axes[0].yaxis.tick_right()

for ax in axes.flat:
    ax.margins(0.03)
    ax.grid(True)

fig.tight_layout()
fig.subplots_adjust(wspace=0.2)
plt.show()

# %% [markdown]
# В 2015 году мужская смертность от внешних трамв примерно одинакова с 30 до 75 лет, ее значения сильно (в 2 раза и более) превосходят смертность женщин, которая растет вместе с повышением возраста.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

age = ["<1", "15-19", "30-34", "40-44", "60-64", "70-74", "80-84"]
m = np.array([192, 536, 1280, 1296, 1233, 1262, 1433])
w = [161, 199, 248, 276, 265, 342, 499]

idx = m.argsort()
age, m, w = [np.take(x, idx) for x in [age, m, w]]

y = np.arange(w.size)

fig, axes = plt.subplots(ncols=2, sharey=True)
axes[0].barh(y, m, align='center' , color='orange', zorder=10)
axes[0].set(title='Men injuries 2011')
axes[1].barh(y, w, align='center', color='orange', zorder=10)
axes[1].set(title='Women injuries 2011')

axes[0].invert_xaxis()
axes[0].set(yticks=y, yticklabels=age)
axes[0].yaxis.tick_right()

for ax in axes.flat:
    ax.margins(0.03)
    ax.grid(True)

fig.tight_layout()
fig.subplots_adjust(wspace=0.2)
plt.show()

# %% [markdown]
# Состояние 2011 года схоже с состоянием 2015. Показатель с 30 до 40 лет лишь немногим меньше смертности в 80-84 года. В целом смертность от трамв уменьшилась за пять лет незначительно.

# %% [markdown]
# ## Задача 2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X = stats.uniform(loc=0, scale=1)
X_values = X.rvs(7000)
sns.distplot(X_values)

# %%
X1 = stats.uniform(loc=0, scale=1)
sns.distplot(np.sum(X1.rvs([3, 2000]), axis=0))

# %%
X2 = stats.uniform(loc=0, scale=1)
sns.distplot(np.sum(X1.rvs([10, 2000]), axis=0))

# %%
X3 = stats.uniform(loc=0, scale=1)
sns.distplot(np.sum(X1.rvs([50, 2000]), axis=0))

# %% [markdown]
# ## Задача 37 Труэль
# Порядок стрельбы задан условием задачи: А-В-С-А-...
# #### Оптимальные стратегии
#
# Оптимальная стратегия игрока А (вероятность попадания 0,6) - в любом случае будет стрелять в противника, так как его вероятность попасть больше, чем у остальных, а вероятность, что попадут в него, меньше.
#
# Оптимальная стратегия игрока С (вероятность попадания 0,4) - стрелять в воздух до того момента, как в игре останутся два игрока (С + А/В). Так он дает сильным игрокам возможность "разобраться" друг с другом, и если один убивает другого, то следующим ходом он первым имеет возможность уничтожить оставшегося ( пусть и с небольшой вероятностью). В противном случае, если он убивает А, то следующим ходом с большой вероятность В убьет его самого.
#
# Оптимальная стратегия игрока В (вероятность попадания 0,5) совпадает со стратегией игрока А (может быть, В и выгодно бы было отклонятся, но он понимает стратегию С и в таком случае не будет стрелять в воздух).

# %% [markdown]
# #### Поиск вероятностей
# ![](http://s019.radikal.ru/i640/1612/54/569cd4709e66.jpg)
# ##### Решение по дереву вероятностей
#
# **1)** Если первым выстрелом А убил В (с вероятностью 0,6), то шанс победить остается у А и у С. Вероятность, что дальше С попадет в цель своим первым выстрелом и победит = 0,24. Если же С промахивается, а следующим ходом А его убивает, то А побеждает с вероятностью 0,216. Если А промахивается, то исход дуэли решает С и цикл повторяется. Можно заметить, что вероятность победы любого из них - сумма бесконечно убывающей геометрической прогресии.
#
# Вероятность победы С = 0,24/(1-0,24) = **0,32**
#
# Верроятность победы А = 0,216/(1-0,24) = **0,28**

# %% [markdown]
# **2)** Если первым выстрелом А не убивает В, то
#
# а) следующим ходом В убивает С и победа разыгрывается между А и В;
#
# б) В не убивает С, тогда (С стреляет в воздух) либо А убивает В, либо промахивается, и ход опять падает на В (при этом все живы) - цикл повторяется.
#
# а) Вероятность победы А = 0,12/(1-0,2) = 0,15
#
# Вероятность победы В = 0,04/(1-0,2) = 0,05
#
# б) Теперь можно учесть повтор цикла для вероятности А и В (случай, когда А промахнулся и ход опять перешел В)
#
# Вероятность победы А = 0,15/(1-0,2) = **0,19**
#
# Вероятность победы В = 0,05/(1-0,2) = **0,06**
#
# Если же А сразу убивает В, то (учитывая все циклы)
#
# Вероятность победы А = (0,0432/(1-0,24))/(1-0,2) = **0,07**
#
# Вероятность победы С = (0,048/(1-0,24))/(1-0,2) = **0,08**

# %% [markdown]
# #### Проверим сумму вероятностей
# 0,32 + 0,28 + 0,19 + 0,06 + 0,07 + 0,08 = **1**
#
# #### Результат
# Вероятность победы А = 0,28 + 0,19 +0,07 = **_0,54_**
#
# Вероятность победы В = **_0,06_**
#
# Вероятность победы С = 0,32 + 0,08 = **_0,4_**
