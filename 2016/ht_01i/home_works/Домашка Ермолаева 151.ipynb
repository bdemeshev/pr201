# %% [markdown]
# # Домашнее задание

# %% [markdown]
# ## Ермолаева Алина. БЭК 151

# %% [markdown]
# ### Задание 1

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import bokeh as bk
import scipy.stats as stats
import numpy as np
# %matplotlib inline

# %%
weather = pd.read_csv("C:\Алина/weather.csv")

# %%
weather.head()
# Out:
#          Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 0  10/13/2014                 71                62.0                54
# 1  10/14/2014                 63                59.0                55
# 2  10/15/2014                 62                58.0                54
# 3  10/16/2014                 71                61.0                52
# 4  10/17/2014                 64                60.0                57
#
#    Max_Dew_Point_F  MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  \
# 0               55               51              46            87
# 1               52               51              50            88
# 2               53               50              46            87
# 3               49               46              42            83
# 4               55               51              41            87
#
#    Mean_Humidity  Min_Humidity   ...    Mean_Sea_Level_Pressure_In  \
# 0             68            46   ...                         29.79
# ...

# %%
sns.distplot(weather['Max_Temperature_F'])
plt.xlabel("Temperature_F")
# Out:
# C:\Users\Александр\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# Гистограмма показывает распределение температуры в течение рассматриваемого промежутка времени

# %%
sns.distplot(weather['Mean_Sea_Level_Pressure_In'])
# Out:
# C:\Users\Александр\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# Гистограмма показывает распределение среднего значения давления на уровне моря в течение рассматриваемого периода

# %%
function = Series(weather ['Max_Humidity'])
function.plot(kind='kde')
plt.xlabel("Max_Humidity")

# %% [markdown]
# График показывает плотность распределения максимальной влажности в течение рассматриваемого периода

# %%
k=weather.head(20)['Min_Humidity']
l=list(k)
a=list(weather.head(20)['Date'])
s = DataFrame({'Date': a, 'Min_Humidity' : l })
m = np.arange(len(l))
plt.barh(m, l)

for p, a, t in zip(pos, a, l):
    plt.annotate(str(t), xy=(t+1, p+ .5), va= 'center')
    ticks = plt.yticks(pos+0.5, weather.head(20)['Date'])
    v = plt.xticks()[0]
    plt.xticks(xt, [''] * len(v))
    plt.xlabel("Min_Humidity")

# %% [markdown]
# Диаграмма показывает различные уровни минимальной влажности в разные дни.

# %%
sns.lmplot('MeanDew_Point_F', 'Mean_Humidity', data = weather)

# %% [markdown]
# График показывает зависимость уровня средней владности от количества выпавшей росы.

# %%
k=weather.head(20)['Max_Temperature_F']
l=list(k)
a=list(weather.head(20)['Date'])
s = DataFrame({'Date': a, 'Max_Temperature_F' : l })
m = np.arange(len(l))
plt.barh(m, l)

for p, a, t in zip(pos, a, l):
    plt.annotate(str(t), xy=(t+1, p+ .5), va= 'center')
    ticks = plt.yticks(pos+0.5, weather.head(20)['Date'])
    v = plt.xticks()[0]
    plt.xticks(xt, [''] * len(v))
    plt.xlabel("Max_Temperature_F")

# %% [markdown]
# Показана максимальная темапература в градусах Фаренгейта в различные дни

# %%
sns.lmplot('Min_Visibility_Miles', 'Mean_Wind_Speed_MPH', data = weather)

# %% [markdown]
# График зависимости минимального уровня видимости и силы ветра

# %%
sns.jointplot(data=weather, x= 'Min_TemperatureF', y='Min_Humidity')

# %% [markdown]
# Показывает взаимосвязь минимального уровня температуры и влажности, тренда нет определенного.

# %%
sns.regplot(x='Max_Dew_Point_F', y='Max_Humidity', data=weather); plt.show()

# %% [markdown]
# Отражает данные максимального уровня влажности и уровня росы. Показывает взаимосвязь этих 2 величин.

# %%
function = Series(weather ['MeanDew_Point_F'])
function.plot(kind='kde')
plt.xlabel("MeanDew_Point_F")

# %% [markdown]
# График показывает плотность распределения среднего уровня росы с в течение рассматриваемого периода.

# %% [markdown]
# ### Задание 2

# %%
xi = stats.uniform(loc=0, scale=1)

# %%
X1 = xi.rvs(100000)

# %%
sns.distplot(X1)
plt.xlabel("Гистограмма распределения Х1")
# Out:
# C:\Users\Александр\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
X2 = xi.rvs(100000)
X3 = xi.rvs(100000)

# %%
sns.distplot(X1+X2+X3)
plt.xlabel("Гистограмма распределения Х1+Х2+Х3")
# Out:
# C:\Users\Александр\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
s = 0
for i in range (10):
    x = stats.uniform(0,1)
    V = x.rvs(100000)
    s += V
sns.distplot(s)
# Out:
# C:\Users\Александр\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
s2 = 0
for i in range (50):
    Y = stats.uniform(0,1)
    Vi = Y.rvs(100000)
    s2 += Vi
sns.distplot(s2)
# Out:
# C:\Users\Александр\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# Пункт 2

# %% [markdown]
# Для оценки вероятности необходимо выписать функцию плотности для 3 случайных величин. Ее интеграл - функция распределения, которая при подстановке 2 даст вероятность того, что сумма 3 случайных величин меньше 2. Поэтому для ответа на поставленный вопрос вычтем из 1 полученный ранее результат.

# %%
import sympy

# %%
x = sympy.symbols('x')
f = 0.5*x**2
f1 = 0.5*(-2*x**2+6*x-3)
h = sympy.integrate(f1,(x,1,2))
z = sympy.integrate(f,(x,0,1))
1-z-h
# Out:
# 0.166666666666667

# %% [markdown]
# Пункт 3

# %%
#Поиск матожидания
xi = stats.uniform(loc=0, scale=1) 
g = xi.rvs(100000)
G = g ** 5
np.mean(G)
# Out:
# 0.16695135663870708

# %% [markdown]
# Полученное число - математическое ожидание от $x^5$

# %%
c = 0
d = np.random.uniform(0,1,100000)
d1=d ** 5
for i in range(100000):
    c=c+d[i] ** 5
print(c/100000) #искомое
# Out:
# 0.167154893075

# %% [markdown]
# Найдем теперь дисперсию

# %%
q1 = np.random.uniform(0,1,100000)
q2 = np.random.uniform(0,1,100000)
j = 0
j1 = 0
for i in range(100000):
    j = j + (q1[i]/(q2[i] ** 2+1))**2
    j1 = j1 + (q1[i]/(q2[i]**2+1))
j1 = j1/100000
j = j/100000
var = j - j1 ** 2
var
# Out:
# 0.059788903963905488

# %% [markdown]
# Пункт 4

# %% [markdown]
# Оценка квантили

# %%
x1 = np.random.uniform(0,1,100000)
x2 = np.random.uniform(0,1,100000)
for i in range(100000):
    x1[i]=x1[i]+1
    x2[i]=x2[i]+3
    x1[i]=x1[i]/x2[i]
b = np.percentile(x1, 25)
b
# Out:
# 0.35689312015785951

# %%
xi = stats.uniform(loc=0, scale=1) 
X1 = xi.rvs(100000)
X2 = xi.rvs(100000)
A = (1+X1)/(3+X2)
M = np.median(A)
M
# Out:
# 0.42861085571993018

# %% [markdown]
# ### Задача 3 (№14 из подборки красивых задач)

# %% [markdown]
# Максимальное число партий, сыгранное Машей и Сашей = 20. В первой партии Маша играет белыми, и выигрывает с вероятностью p>0,5.
#
# Независимо от правил Маша может сыграграть максимум 10 раз, а Саша не больше 9. Победитель точно определится за 19 партий. Победитель - игрок, выигрывший в большем числе партий, а значит Машин шанс
# выиграть не зависит от выбранного варианта правил.
