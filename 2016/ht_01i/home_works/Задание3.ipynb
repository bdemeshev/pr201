# %% [markdown]
# Решение 6 номера из культурного кода

# %% [markdown]
# Нарисуем дерево с вероятностями

# %%
from IPython.display import Image
Image("/Users/garik/Desktop/pordz.jpg",width=500, height=100)

# %% [markdown]
# 1.P(Вероятность того, что фотон в состоянии $α$ пройдет через фильтр с параметром $θ = 0$) = $1 - sin^2(α-0)$ = $cos^2(α)$

# %% [markdown]
# 2.P(Фотон пройдет сквозь фильтр с параметром $θ = 0$, переходя в состояние 0) = $1 - sin^2(α)$ = $cos^2(α)$

# %% [markdown]
# P(Фотон в состоянии 0 пройдет сквозь фильтр с параметром $θ = π/2$) =   $1−sin^2(0-π/2)$ = $cos^2(-π/2)$

# %% [markdown]
# Ответ: P(Фотон пройдет сквозь первый фильтр с $θ = 0$ и сквозь второй фильтр $θ=π/2$ ) = $cos^2(α)*cos2(−π/2)$ =0

# %% [markdown]
# 3.P(Фотон проходит сквозь фильтр с параметром θ = 0,переходя в состояние 0) = $1 - sin^2(α)$ = $cos^2(α)$

# %% [markdown]
# P(Фотон в состоянии 0 проходит сквозь фильтр с параметром $θ = β$,переходя в состояние β) =   $1−sin^2(0-β)$ = $cos^2(-β)$

# %% [markdown]
# P(Фотон в состоянии β проходит сквозь фильтр с параметром $θ = π/2$) =   $1−sin^2(β-π/2)$ = $cos^2(β-π/2)$

# %% [markdown]
# Вероятонсть того, что фотон пройдет поочереди по всем 3 фильтрам равняется

# %% [markdown]
# Ответ: P = $cos^2(α)*$$cos^2(-β)*$$cos^2(β-π/2)$
#
# Максимизируя вероятность получаем $α = π/2,β = π/4$
#
# При этих значениях P = 1/4

# %% [markdown]
# 4.Данный фокус объясняется с помощью уже решенных пунктов 2 и 3.
#
# В пункте 2 мы доказали,что при любых $α$ вероятность того, что свет сначала пройдет сквозь фильтр с параметром $θ = 0$, а потом сквозь фильтр с параметром $θ=π/2$ равняется 0. В пункте 3 мы доказали, что если $α = п/2$ и между этими фильтрами ставить другой фильтр с параметром $β=π/4$, то всегда будет существовать вероятность(1/4), что свет пройдет сквозь 3 фильтра/стекла. Именно этим и объясняется почему свет не проходит сквозь 2 стекла, а когда между ними ставишь другое стекло, то он начинает проходить сквозь 3 стекла.
