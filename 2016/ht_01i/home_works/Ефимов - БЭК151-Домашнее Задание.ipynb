# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Задание 1

# %%
iris = pd.read_csv('/Users/Andryusha/Desktop/iris.csv')

# %% [markdown]
# Хоть данные не очень интересные, зато графики красивые(:

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.jointplot(data=iris,x="PetalLengthCm",y = "PetalWidthCm",kind='kde')
# Out:
# /Users/Andryusha/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# Этот график демонстрирует, что между шириной и длинной лепестков ириса есть определенная зависимость. А еще он очень он хорошо отражает, какое отношение ширины к длинне встречается чаще всего

# %%
sns.FacetGrid(iris, hue="Species", size=5) \
   .map(plt.scatter, "SepalLengthCm", "SepalWidthCm") \
   .add_legend()

# %% [markdown]
# Этот график показывает зависимость между длинной и шириной чашелистика ириса. Ее практически нет. Зато на графике все отмечены виды ириса. Внутри вида, похоже, зависимость сильнее.

# %%
sns.distplot(iris.SepalWidthCm)
# Out:
# /Users/Andryusha/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# На графике отражено распределение ширины чашелистика. Распределение очень похоже на нормальное.

# %%
ax = sns.boxplot(x="Species", y="PetalLengthCm", data=iris)
ax = sns.stripplot(x="Species", y="PetalLengthCm", data=iris, jitter=True, edgecolor="gray")

# %% [markdown]
# На данном графике отражен разброс длинны лепестка каждого вида ириса.

# %%
sns.FacetGrid(iris, hue="Species", size=6) \
   .map(sns.kdeplot, "PetalLengthCm") \
   .add_legend()
# Out:
# /Users/Andryusha/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# Здесь видна зависимость длины чашелистика от вида ириса.

# %%
sns.pairplot(iris.drop("Id", axis=1), hue="Species", size=3)

# %% [markdown]
# На этом графике отражено все сразу(зависимость длины и ширины как чашелистика, так и лепестка)

# %%
from pandas.tools.plotting import andrews_curves
andrews_curves(iris.drop("Id", axis=1), "Species")

# %% [markdown]
# Я плохо представляю что это такое, но это красиво. Гворят, это так называемые Andrews Curves.
#
# А вот, что они делают: Andrews curves allow one to plot multivariate data as a large number of curves that are created using the attributes of samples as coefficients for Fourier series. By coloring these curves differently for each class it is possible to visualize data clustering.

# %%
from pandas.tools.plotting import radviz
radviz(iris.drop("Id", axis=1), "Species")

# %% [markdown]
# Алгоритм автоматически находит среднее значение, берет его за 0 и показывает, как разные параметры откланяются от этого 0. Все масштабированно к 1.

# %%
sns.violinplot(x="Species", y="SepalLengthCm", data=iris, size=6)

# %% [markdown]
# Этот график показывает, как зависит длина чашелистика от вида.

# %%
sns.barplot(data=iris,x ="Species", y = "SepalWidthCm")

# %% [markdown]
# Здесь отражена средняя ширина чашелистика в каждом виде.

# %% [markdown]
#  Очень крутой сайт, который помогает изучить основы http://blog.insightdatalabs.com/advanced-functionality-in-seaborn/

# %% [markdown]
# ## Задание 2

# %% [markdown]
# ## 1

# %%
X = stats.uniform(loc=0, scale = 1)
x1 = X.rvs(1000000)

# %%
sns.distplot(x1)
# Out:
# /Users/Andryusha/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
Z = stats.uniform(loc=0, scale = 1)
z1 = Z.rvs([1000000,3])
z1
sns.distplot(np.sum(z1, axis=1))
# Out:
# /Users/Andryusha/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
Z = stats.uniform(loc=0, scale = 1)
z1 = Z.rvs([1000000,10])
z1
sns.distplot(np.sum(z1, axis=1))
# Out:
# /Users/Andryusha/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
Z = stats.uniform(loc=0, scale = 1)
z1 = Z.rvs([1000000,50])
z1
sns.distplot(np.sum(z1, axis =1))
# Out:
# /Users/Andryusha/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# ## 2

# %%
Z = stats.uniform(loc=0, scale = 1)
z1 = Z.rvs([1000000,3])
z = np.sum(z1, axis=1)
np.sum(z>2)/1000000
# Out:
# 0.16658400000000001

# %% [markdown]
# ## 3

# %%
np.mean(x1**5)
# Out:
# 0.16657312626062901

# %%
y = x1/(1+y1**2)
y.var()
# Out:
# 0.060072312061928722

# %% [markdown]
# ## 4

# %%
y =((1+x1)/(3+y1))
np.median(y)
# Out:
# 0.42859474668427539

# %%
np.percentile(a=y,q=25)
# Out:
# 0.35728176550085156

# %% [markdown]
# # Задание 3
# ### ВОЛШЕБНЫЕ МОНЕТКИ( (№18)

# %% [markdown]
# #### Сколько нужно сделать бросков до ОРОР? до РОРР?

# %% [markdown]
# Воспользуемся интересным методом, который описан в статье "A Martingale Approach to the Study of Occurrence of Sequence Patterns in Repeated Experiments" (http://projecteuclid.org/DPubS?service=UI&version=1.0&verb=Display&handle=euclid.aop/1176994578)
#
# Коротко говоря, он заключается в том, что игроки учавствуют в честной лотерее(если поставил 1\$: выиграл-получаешь 2, включая поставленный 1; проиграл - у тебя 0).
# Допустим у нас есть последовательность ОРРРОРОР. Выигрышная последовательность ОРОР. Все ставят на то, что в следующий ход выиграет эта комбинация следующим образом: Ставится 1\$ на то, что выпадет О. Если выпадает О, тогда игрок обязан поставить полученные 2 доллара на Р. Если опять выиграл, то обязан поставить все 4 выигранных доллра на Р и тд. Если проиграл, то выбывает игрок теряет деньги и выбывает из игры.
# Кроме того, игроки вступают в игру так: в первый раз ставит 1 игрок, во второй раз игроки 1 и 2(если 1 не проиграл до этого), в третий раз учвствуют игроки 1, 2, 3( опять же, если один или оба не выбыли в результате прошлого кона)
# В конце концов считается чистый выигрыш и ожидемое колличество бросков.
# В нашем случае что-то выиграют 5 и 7 игроки(у 5 выигрыш = 16, у 7 - 4)
# Чистый выигрыш = $20 - N$, где N - колличество ходов до ОРОР. Но раз организованная лотерея имеет нулевое математическое ожидание выигрыша на каждом ходу, значит мат ожидание финального благосостояния игрока равно стартовому благосостоянию. Тогда EN = 20.
#
# Итого, ожиаемое колличество ходов:
#
# до $ ОРОР = 16+4 = 20$
#
# до $РОРР = 16+2 =18$
#
# Есть и еще один метод решения, изложенный в "DNA, Words And Models" by Robin, Rodolphe, and Schbath. Авторы объясняют, почему математическое ожидание есть сумма обратных вероятностей каждого префикса в слове, который также является суффиксом этого же слова. В случае ОРОР такие суффиксы-префиксы это ОРОР и ОР, в случае РОРР это РОРР и Р. Удивительно, но результат окажется таким же, как при предыдущем методе решения.
#
#
# А вообще, это все можно вывести самостоятельно, вот пример, если нужно найти количество бросков до ОРО:
# $$
# \begin{align}
# E(0) &= \frac{1}{2} (E(О) + 1) + \frac{1}{2} (E(0) + 1)\\
# E(О) &= \frac{1}{2} (E(О) + 1) + \frac{1}{2} (E(ОР) + 1)\\
# E(ОР) &= \frac{1}{2} (E(ОРО) + 1) + \frac{1}{2} (E(0) + 1)\\
# E(ОРО) &= 0
# \end{align}
# $$
#
# По аналогии можно найти и количество бросков до ОРОР, и до РОРР

# %% [markdown]
# #### Какова вероятность того, что ОРОР появится раньше РОРР?

# %% [markdown]
# Пусть у меня есть какие-то состояние
# p_{0,0} - это верятность того, что ОРОР появится раньше РОРР, но еще не выпал ни орел, ни решка.
#
# Тогда с вероятностью 0,5 я окажусь в состоянии $p_{0,1}$(выпала решка) и с 0,5 в состоянии $p_{1,0}$(выпал орел).
#
# Получаем:
# $p_{0,0}=0,5p_{0,1}+0,5p_{1,0}$.

# %% [markdown]
# Таким образом, в конце концов я смогу составить систему
# $$
# \begin{cases}
# 2p_{0,0}=p_{0,1}+p_{1,0}\\
# 2p_{0,1}=p_{0,1}+p_{1,2}\\
# 2p_{1,0}=p_{2,1}+p_{1,0}\\
# 2p_{1,2}=p_{2,3}+p_{1,0}\\
# 2p_{2,1}=p_{0,1}+p_{3,2}\\
# 2p_{2,3}=p_{0,4}+p_{3,2}=p_{3,2}\\
# 2p_{3,2}=p_{4,3}+p_{0,0}=1+p_{1,0}\;,
# \end{cases}
# $$
# где $p_{0,4} = 0$ и $p_{4,3} = 1$

# %% [markdown]
# Можно переписать систему как
# $$
# \begin{cases}
# 2p_{0,0}=p_{1,2}+p_{2,1}\\
# 2p_{1,2}=p_{2,3}+p_{2,1}\\
# 2p_{2,1}=p_{1,2}+2p_{2,3}\\
# 4p_{2,3}=1+p_{2,1}\;,
# \end{cases}
# $$

# %% [markdown]
# Решив ее, получаем ответ $ p_{0,0} = 9/14$

# %% [markdown]
# #### Какова вероятность того, что ООО появится позже РРОО? (РРОО появится раньше)

# %% [markdown]
# Воспользуемся методом из Section 8.4 ("Flipping Coins") из Concrete Mathematics
# Найдему сумму всех возможных кобинаций,
#
# Где побеждает РРОО:
#
# $ S_{1} = РРОО +ОРРОО+РРРОО+ОРРРОО+РОРРОО+...$
#
# Где побеждает ООО:
#
# $S_{2} = ООО+ РООО+ОООО+ОРООО+...$
#
# Где никто не побеждает:
#
# $N= 1 + О+Р+ОР+ОО+РО+...$
#
# Тогда, если мы заменим О и Р на вероятности их появления(0,5 и 0,5), то получим: вероятность победы первой комбинации, вероятность выигрыша второй комбинации и матемачиское ожидание окончания игры.
#
# Составим 3 уравнения:
# $$
# \begin{cases}
# N ООО = S_{2} +S_{2} О + S_{2}ОО + S_{1}О + S_{1} ОО\\
# N РРОО = S_{1} \\
# S_{1} + S_{2} = 1\\
# \end{cases}
# $$
# То есть мы к $N$ добавляем искомые комбинации и смотрим, как это все расскладывается.

# %%
M1 = np.array([[1.25, -1.75], [1.00, 1.00]]) 
v1 = np.array([0.00, 1.00])
np.linalg.solve(M1, v1)
# Out:
# array([ 0.58333333,  0.41666667])

# %% [markdown]
# Ответ: P = 0.58333333

# %% [markdown]
# #### ООР раньше чем ОРР?
# Не будем долго думать и воспользуемся уже известным способом
# $$
# \begin{cases}
# NООР = S_{1}\\
# NОРР = S_{2} +S_{1} P\\
# S_{1} + S_{2} = 1\\
# \end{cases}
# $$
#
#
# #### ОРР раньше РРО?
# $$
# \begin{cases}
# NОРР = S_{1}  + S_{2}РР\\
# NРРО = S_{2}+ S_{1} РО+S_{1} О\\
# S_{1} + S_{2} = 1\\
# \end{cases}
# $$
# #### РРО ранше РОО?
# $$
# \begin{cases}
# NРРО = S_{1} \\
# NРОО = S_{2}+ S_{1} О\\
# S_{1} + S_{2} = 1\\
# \end{cases}
# $$
# #### РОО раньше ООР?
# $$
# \begin{cases}
# NРОО = S_{1} + S_{2}ОО\\
# NООР = S_{2} +S_{1} ОР +S_{1} Р\\
# S_{1} + S_{2} = 1\\
# \end{cases}
# $$

# %%
#ООР раньше чем ОРР
M1 = np.array([[-0.50, 1.00], [1.00, 1.00]]) 
v1 = np.array([0.00, 1.00])
np.linalg.solve(M1, v1)
# Out:
# array([ 0.66666667,  0.33333333])

# %% [markdown]
# P =  0.66666667

# %%
#ОРР раньше РРО?
M1 = np.array([[-0.25, 0.75], [1.00, 1.00]]) 
v1 = np.array([0.00, 1.00])
np.linalg.solve(M1, v1)
# Out:
# array([ 0.75,  0.25])

# %% [markdown]
# Р = 0.75

# %%
#РРО ранше РОО?
M1 = np.array([[-0.50, 1.00], [1.00, 1.00]])
v1 = np.array([0.00, 1.00])
np.linalg.solve(M1, v1)
# Out:
# array([ 0.66666667,  0.33333333])

# %% [markdown]
# Р = 0.66666667

# %%
#РРО раньше ООР?
M1 = np.array([[-0.25, 0.75], [1.00, 1.00]])
v1 = np.array([0.00, 1.00])
np.linalg.solve(M1, v1)
# Out:
# array([ 0.75,  0.25])

# %%
Р = 0.75
