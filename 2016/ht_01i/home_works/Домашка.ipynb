# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
import scipy.integrate as integrate
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
 mov = pd.read_csv('/Users/tata/Downloads/movie_metadata.csv')

# %%
sns.jointplot(data = mov, x = "imdb_score" , y = "movie_facebook_likes" )

# %%
from scipy.stats import kendalltau
sns.set(style="ticks")
sns.jointplot(data = mov, x = "imdb_score" , y = "movie_facebook_likes", stat_func=kendalltau, color="#594bb2")

# %% [markdown]
# Извините, что без графиков :с
#
# Времени чего-то совсем не хватает, чувствую себя жуутким лохом! :о :"С
#
# Но когда-нибудь обязательно научусь!!!! Обещаю!
#
# Вы самый лучший!

# %% [markdown]
# # Намбер Ту

# %%
X = stats.uniform(loc=0, scale=1)
X_values = X.rvs(7000)
sns.distplot(X_values)
# Out:
# /Users/tata/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
X1 = stats.uniform(loc=0, scale=1)
sns.distplot(np.sum(X1.rvs([3, 1000]), axis=0))
# Out:
# /Users/tata/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
X2 = stats.uniform(loc=0, scale=1)
sns.distplot(np.sum(X1.rvs([10, 1000]), axis=0))
# Out:
# /Users/tata/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
X3 = stats.uniform(loc=0, scale=1)
sns.distplot(np.sum(X1.rvs([50, 1000]), axis=0))
# Out:
# /Users/tata/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
X1 = stats.uniform(0,1)
X2 = stats.uniform(0,1)
X3 = stats.uniform(0,1)
XXX = X1.rvs(10000000) + X2.rvs(10000000) + X3.rvs(10000000)
np.sum(XXX>2)/(len(XXX))
# Out:
# 0.16657089999999999

# %%
E = integrate.quad(lambda t: t**5, 0, 1)
print(E[0])
# Out:
# 0.16666666666666669

# %% [markdown]
# или же простой способ:

# %%
np.mean(X1.rvs(10000)**5)
# Out:
# 0.16626079299789653

# %%
VarX1 = X1.var()
VarX1
# Out:
# 0.083333333333333329

# %% [markdown]
# $ T = E((X_1/(1 + X_2^2))^2) = E(X_1^2)/E(1 + 2X_2^2 + X_2^4) $
#
# $ O = E(X_1/(1 + X_2^2)) = E(X_1)/E(1 + X_2^2)$ т.к. величины независимые!

# %%
X1_values = X1.rvs(100000)
X2_values = X2.rvs(100000)
T = np.mean(X1_values**2)/(1 + 2*np.mean(X2_values**2) + np.mean(X2_values**4))

O = (np.mean(X1_values))**2 / ((np.mean(X2_values**2)) + 1)**2
Varrr = T - O
Varrr
# Out:
# 0.038206222221674052

# %%
Bobrenok = (X1_values + 1)/(X2_values + 3)
Ch = np.percentile(V, 25) 
M = np.percentile(V, 50)

# %%
Ch #chetvert'
# Out:
# 0.35720044364843073

# %%
M #Middle
# Out:
# 0.42856999597928186

# %% [markdown]
# # Задачка

# %% [markdown]
# Возможные варианты:
#
# А Б В
#
# А В Б
#
# Б А В
#
# Б В А
#
# В А Б
#
# В Б А

# %% [markdown]
# Придумаем такую стратегию:
#
# Пусть Андрюша всегда выбирает первую и вторую коробку.
# Тогда он проиграет с вероятностью 1/3. Игра заканчивается.
#
# Если же он окажется прав (с вероятностью 2/3) он выходит. Тогда мы знаем, что возможны только наборы:
#
# А Б В
#
# А В Б
#
# Б А В
#
# В А Б
#
# Пусть он выбирает 2 и 3 коробку. С вероятностью 3/4 он выбирает нужную. Тогда остаются:
#
# А Б В
#
# А В Б
#
# В А Б
#
# Тогда 3 выбирает 1 и 3 коробку (тут уже без разницы) и выбирает правильную с вероятностью 2/3.
#
# Тогда имеем:

# %%
2/3 * 3/4 * 2/3
# Out:
# 0.3333333333333333

# %% [markdown]
# Ничего более вероятностного не приходит в голову...
